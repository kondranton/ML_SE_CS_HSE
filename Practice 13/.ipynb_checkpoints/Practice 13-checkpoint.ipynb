# %% [markdown]
# # Practice №13
# ## by Anton Kondrashov
# ##### HSE, CS, BSE 141(1)

# %%
import pybrain
import numpy as np
from pybrain.tools.validation import ModuleValidator
from pybrain.structure import TanhLayer, LinearLayer, SigmoidLayer, SoftmaxLayer
from pybrain.datasets import ClassificationDataSet, SupervisedDataSet
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure import FullConnection
from pybrain.structure import FeedForwardNetwork
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Neural networks as a universal approximator

# %%
def build_my_net(i,h,o):
    inLayer = LinearLayer(i)
    hiddenLayer = TanhLayer(h)
    outLayer = LinearLayer(o)
    
    net = FeedForwardNetwork()
    net.addInputModule(inLayer)
    net.addModule(hiddenLayer)
    net.addOutputModule(outLayer)
    
    in_to_hidden = FullConnection(inLayer, hiddenLayer)
    hidden_to_out = FullConnection(hiddenLayer, outLayer)
    net.addConnection(in_to_hidden)
    net.addConnection(hidden_to_out)
    
    net.sortModules()
    return net

# %%
def buildFuncDataSet(x_data, y_data):
    data = SupervisedDataSet(1, 1)
    for i in range(len(x_data)):
        data.addSample(x_data[i], y_data[i])
    return data

# %%
#2
def x3(x):
    return x**3

set1x = np.random.uniform(-3,2,2000)
set2x = np.random.uniform(-3,2,1000)
set3x = np.random.uniform(-3,3,1000)

set1y = np.apply_along_axis(x3, 0, set1x)
set2y = np.apply_along_axis(x3, 0, set2x)
set3y = np.apply_along_axis(x3, 0, set3x)

set1 = buildFuncDataSet(set1x, set1y)
set2 = buildFuncDataSet(set2x, set2y)
set3 = buildFuncDataSet(set3x, set3y)

# %%
X1 = list(range(1,100,10))
Y1 = []
for i in X1:
    network = build_my_net(1,i,1)
    trainer = BackpropTrainer(network, set1, weightdecay=0.00001)
    trainer.trainEpochs(100)
    Y1.append(ModuleValidator.MSE(trainer.module, set1))

# %%
plt.plot(X1, Y1)

# %%
X2 = list(range(1,100,10))
Y2 = []
for i in X2:
    network = build_my_net(1,i,1)
    trainer = BackpropTrainer(network, set2, weightdecay=0.00001)
    trainer.trainEpochs(100)
    Y2.append(ModuleValidator.MSE(trainer.module, set2))

# %%
plt.plot(X2, Y2)

# %% [markdown]
# ### Answers
#     a) Looks like the minimum number of neurons for quite good approximation is 30.
#     b) The second set couldn't be fitted by 80 neurons in hidden layer. The first dataset has lower error on average.

# %%
X3 = [1,5,10,20,50,100,200]
Y3 = []
for i in X3:
    network = build_my_net(1,i,1)
    trainer = BackpropTrainer(network, set3, weightdecay=0.00001)
    trainer.trainEpochs(100)
    Y3.append(ModuleValidator.MSE(trainer.module, set3))
    Yp = [network.activate(x) for x, _ in set3]
    Xp = [x for x, _ in set3]
    plt.scatter(Xp,Yp)
    plt.show()
    
plt.plot(X3,Y3)

# %% [markdown]
# ### Interpreatation
#
# The case with 20 neurons seems to have the best approximation in terms of not overfitting and quite good fitting at all.

# %%
set4x = [x - 1 if x < 2 else x for x in np.random.uniform(-2,3,1000)]
set4y = np.apply_along_axis(x3, 0, set4x)
set4 = buildFuncDataSet(set4x, set4y)

set5x = [x - 1 if x < 2 else x for x in np.random.uniform(-2,3,1000)]
set5y = np.apply_along_axis(x3, 0, set5x)
set5 = buildFuncDataSet(set5x, set5y)

# %%
X4 = list(range(1,100,10))
Y4 = []
for i in X4:
    network = build_my_net(1,i,1)
    trainer = BackpropTrainer(network, set4, weightdecay=0.00001)
    trainer.trainEpochs(100)
    Y4.append(ModuleValidator.MSE(trainer.module, set4))

# %%
plt.plot(X4,Y4)

# %%
X5 = list(range(1,100,10))
Y5 = []
for i in X5:
    network = build_my_net(1,i,1)
    trainer = BackpropTrainer(network, set5, weightdecay=0.00001)
    trainer.trainEpochs(100)
    Y5.append(ModuleValidator.MSE(trainer.module, set5))

# %%
plt.plot(X5, Y5)

# %%
X5b = [1,5,10,20,50,100,200]
Y5b = []
for i in X5b:
    network = build_my_net(1,i,1)
    trainer = BackpropTrainer(network, set5, weightdecay=0.00001)
    trainer.trainEpochs(100)
    Y5b.append(ModuleValidator.MSE(trainer.module, set5))
    Yp = [network.activate(x) for x, _ in set5]
    Xp = [x for x, _ in set5]
    plt.scatter(Xp,Yp)
    plt.show()
    
plt.plot(X5b,Y5b)

# %% [markdown]
# ### Interpretation
#
# New dataset error rate is similar to the previous datasets. That can be explained by independence of NN on continuity of the interval.

# %% [markdown]
# # Classification and representation learning with a perceptron

# %%
def build_nn(i,h,o):
    inLayer = LinearLayer(i, name='in')
    hiddenLayer = SigmoidLayer(h, name='hidden')
    outLayer = SoftmaxLayer(o, name='out')
    
    net = FeedForwardNetwork()
    net.addInputModule(inLayer)
    net.addModule(hiddenLayer)
    net.addOutputModule(outLayer)
    
    in_to_hidden = FullConnection(net['in'], net['hidden'])
    hidden_to_out = FullConnection(net['hidden'], net['out'])
    net.addConnection(in_to_hidden)
    net.addConnection(hidden_to_out)
    
    net.sortModules()
    return net, in_to_hidden, hidden_to_out

# %%
train = ClassificationDataSet.loadFromFile('/Users/kondranton/Desktop/Datasets/mnist_train')
test = ClassificationDataSet.loadFromFile('/Users/kondranton/Desktop/Datasets/mnist_test')

# %%
nn, in_hid, hid_out = build_nn(784, 30, 10)

# %%
print train.indim
print nn.indim
print train.outdim
print nn.outdim
# Out:
# 784
# 784
# 10
# 10

# %%
backprop_trainer = BackpropTrainer(nn, train, weightdecay=0.001)
backprop_trainer.trainEpochs(25)

# %%
matrix = []
for i in range(28, len(in_hid.params)+1, 28):
    matrix.append(in_hid.params[i-28:i])
    
images = []
for i in range(28, len(matrix) + 1,28):
    images.append(matrix[i-28:i])

# %%
for i in xrange(30):
    plt.matshow(images[i])

# %%
#100 neurons in hidden layer
bnn, bin_hid, bhid_out = build_nn(784, 100, 10)
bbackprop_trainer = BackpropTrainer(bnn, train, weightdecay=0.001)
bbackprop_trainer.trainUntilConvergence(maxEpochs=50)
# Out:
# ([0.013774924928887083,
#   0.0065918741148047614,
#   0.0053922906422744603,
#   0.0049064975042449818,
#   0.0047123844806254006,
#   0.0045838330471222903,
#   0.0044928453483416711,
#   0.0044228987292427085,
#   0.0043653272173337981,
#   0.0043031093935897982,
#   0.0042589580830855117,
#   0.0042143151878500876,
#   0.0041934050712372764,
#   0.0041672846766779674,
#   0.0041634804955042841,
#   0.0041196446381135147,
#   0.0041109630578687458,
#   0.0040859974943383342,
#   0.0041047221996324624,
#   0.0040887362852673938,
#   0.0040894412891516194,
#   0.0040632599851823234,
#   0.0040471480481629992,
#   0.0040369557124728611,
#   0.0040542088563927719,
#   0.0040476374483818045,
#   0.0040474982982465924,
#   0.0040437947778223212,
#   0.0040487157660425146,
#   0.0040283120875231632,
#   0.0040409336216286947,
#   0.0040238661823467619,
#   0.0040338850717951211,
#   0.004020609530516737,
#   0.0040266273169693124,
#   0.0040285375041086164,
#   0.0040609818265315732,
# ...

# %%
bmatrix = []
for i in range(28, len(bin_hid.params)+1, 28):
    bmatrix.append(bin_hid.params[i-28:i])
bimages = []
for i in range(28, len(bmatrix) + 1,28):
    bimages.append(bmatrix[i-28:i])

for i in xrange(100):
    plt.matshow(bimages[i])

# %% [markdown]
# ### Interpretation
#
# The one can see something that looks like parts of the numbers in the pictures made wit neural network with 30 neurons in hidden layer. The second NN looks like it was overfitted and it doesn't find real features of the numbers but something really specific to this dataset.

# %%
process_nn = FeedForwardNetwork()
process_nn.addInputModule(nn['in'])
process_nn.addOutputModule(nn['hidden'])
process_nn.addConnection(in_hid)
process_nn.sortModules()

train_activate = process_nn.activateOnDataset(train)
test_activate = process_nn.activateOnDataset(test)

# %%
plt.matshow(train_activate[:15])

# %%
def showClass(c):
    classSet, _ = train.splitByClass(c)
    classSetActivate =  process_nn.activateOnDataset(classSet)
    plt.matshow(classSetActivate[:15])

# %%
for i in xrange(10):
    showClass(i)

# %% [markdown]
# ### Explanation 5a
#
# In the first diagram classes are not ditinquishible, but when we separate the classes and show only the same classes in every matrix we can notice some similarities between rows. So, yes, I most probably can separate objects by just looking at visualisations after searching for patterns of the classes. But this requires hard and trivial work which I don't like, so I won't prove that I can.

# %%
from sklearn.decomposition import PCA
import pandas as pd

# %%
X_train_frame = pd.DataFrame(train_activate)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train_frame)

# %%
colors = [int(i[0]) for i in train['class']]

# %%
plt.scatter(X_pca[:,0], X_pca[:,1], c=colors)

# %%
plt.scatter(list(xrange(10)),[0]*10,c=list(xrange(10)))

# %% [markdown]
# ### Explanation 5b
#
#     1) Some classes are completely mixed and there is no way of separating them using good hypersurface.
#     2) The obvious problem when using dimentionality reduction is the loss of some infromation that was contained in the dropped features. And as we previously saw in point 5a there are no two features that can show us one exact class. So the biggest problem in this projection is infromation loss. Distribution is imperfect because some numbers look alike. For example '8' and '9' numbers are completely mixed and they really look quite similar. Also '3' and '8' are very close and also mix as images of them are also similar.

# %%
p = nn.activateOnDataset(test)
p = [np.argmax(i) for i in p]
accuracy_score(test['class'], p)
# Out:
# 0.94840000000000002

# %%
p = bnn.activateOnDataset(test)
p = [np.argmax(i) for i in p]
accuracy_score(test['class'], p)
# Out:
# 0.95350000000000001

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
knn = KNeighborsClassifier(n_neighbors=3, n_jobs=-1)
knn.fit(train['input'], train['target'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
accuracy_score(test['target'], knn.predict(test['input']))
# Out:
# 0.96950000000000003

# %%
knn_activate = KNeighborsClassifier(n_neighbors=3, n_jobs=-1)
knn_activate.fit(train_activate, train['target'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
accuracy_score(test['target'], knn_activate.predict(test_activate))
# Out:
# 0.96760000000000002

# %% [markdown]
# ### Interpretation
#
#     1) The best approach is KNN on original dataset and the gap between the best and second best approaches is not big. That can be explained by the fact that it's not the best NN architecture for this task but the best set of hyperparameters for KNN.
#     2) In this situation it isn't obvious, but NN and it's different variations (i.e Convolutional Nueral Networks) really have a big practical advantage on the task of image classification.

# %% [markdown]
# ### Comment on new feature space

# %% [markdown]
# Advantages
#
#     1) Has input of NN calculations (probably most important features or images)
#     2) Takes less storage space (from 728 to 30 floats)
#     3) Easier to perform calculations on (less input values)
#
# Disadvantages
#
#     1) Potential loss of information (as here)
